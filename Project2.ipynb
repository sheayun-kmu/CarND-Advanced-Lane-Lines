# %% [markdown]
# ### Import test driver and run

# %%
# %matplotlib inline
from run import test_undistort
test_undistort()
# Out:
# 2020-09-08 02:00:50 [lanefinder.CamModel] INFO: Beginning camera calibration with 20 images
# 2020-09-08 02:00:50 [lanefinder.CamModel] WARNING: Failed to find 9 * 6 corners from image ./camera_cal/calibration5.jpg
# 2020-09-08 02:00:51 [lanefinder.CamModel] WARNING: Failed to find 9 * 6 corners from image ./camera_cal/calibration4.jpg
# 2020-09-08 02:00:51 [lanefinder.CamModel] WARNING: Failed to find 9 * 6 corners from image ./camera_cal/calibration1.jpg
# 2020-09-08 02:00:53 [lanefinder.CamModel] INFO: Gathered 17 sets of corners
# 2020-09-08 02:00:54 [lanefinder.CamModel] INFO: Finished calibrating camera
